# %%
import pandas as pd
df=pd.read_csv('/Users/nirbhaysedha/Documents/breast_cancer_project/BREAST_CANCER_DETECTION/breast-cancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.drop(columns=['id'],inplace=True)
x=df.iloc[:,1:]
y=df.iloc[:,0]
from sklearn.model_selection import train_test_split

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
# train test split 

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=90)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 498        18.49         17.52          121.30     1068.0          0.10120
# 375        16.17         16.07          106.30      788.5          0.09880
# 253        17.30         17.08          113.00      928.2          0.10080
# 281        11.74         14.02           74.24      427.3          0.07813
# 462        14.40         26.99           92.25      646.1          0.06995
# ..           ...           ...             ...        ...              ...
# 480        12.16         18.03           78.29      455.3          0.09087
# 74         12.31         16.52           79.19      470.9          0.09172
# 402        12.96         18.29           84.18      525.2          0.07351
# 452        12.00         28.23           76.77      442.5          0.08437
# 323        20.34         21.51          135.90     1264.0          0.11700
#
# ...

# %%
from sklearn.decomposition import PCA

extraction=PCA(n_components=5)
x_train_tr=extraction.fit_transform(x_train)
x_test_tr=extraction.transform(x_test)

# %%
principal_components = extraction.components_

# Get the column names of your original dataset
feature_names = list(x.columns)

# Print the feature names that contribute the most to each principal component
for i, component in enumerate(principal_components):
    indices = component.argsort()[::-1]
    top_feature_names = [feature_names[idx] for idx in indices]
    print(f"Principal Component {i+1} top features: {', '.join(top_feature_names)}")
# Out:
# Principal Component 1 top features: area_worst, area_mean, area_se, perimeter_worst, perimeter_mean, radius_worst, radius_mean, texture_worst, perimeter_se, texture_mean, radius_se, concavity_worst, compactness_worst, concavity_mean, concave points_worst, concave points_mean, compactness_mean, symmetry_worst, concavity_se, smoothness_worst, symmetry_mean, compactness_se, smoothness_mean, concave points_se, fractal_dimension_worst, fractal_dimension_se, smoothness_se, symmetry_se, fractal_dimension_mean, texture_se
# ...

# %%
x_train_tr.shape
# Out:
# (455, 5)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train_tr)
x_test=scaler.transform(x_test_tr)

# %%
x_train.shape
# Out:
# (455, 5)

# %%
from sklearn.neighbors import KNeighborsClassifier
model_KNN=KNeighborsClassifier(n_neighbors=10,weights='distance',p=1)

model_KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10, p=1, weights='distance')

# %%
knn_pred=model_KNN.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

print(f"the accuracy of KNN model is {accuracy_score(y_test,knn_pred)}")
print(f"the confusion matrix of KNN model is {confusion_matrix(y_test,knn_pred)}")
pos_label = 'M' 
precision = precision_score(y_test, knn_pred, pos_label=pos_label)
print(f"The precision score of the KNN model is {precision}")
precision = recall_score(y_test, knn_pred, pos_label=pos_label)
print(f"The recall score of the KNN model is {precision}")
print(f"the  f1_score of KNN model is {f1_score(y_test,knn_pred, pos_label=pos_label)}")
# Out:
# the accuracy of KNN model is 0.9210526315789473
# the confusion matrix of KNN model is [[69  1]
#  [ 8 36]]
# The precision score of the KNN model is 0.972972972972973
# The recall score of the KNN model is 0.8181818181818182
# the  f1_score of KNN model is 0.8888888888888891

# %%
from sklearn.linear_model import LogisticRegression
model_lr=LogisticRegression()

model_lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_pred=model_lr.predict(x_test)
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

print(f"the accuracy of Logistic Regression model is {accuracy_score(y_test,lr_pred)}")
print(f"the confusion matrix of Logistic Regression model is {confusion_matrix(y_test,lr_pred)}")
pos_label = 'M' 
precision = precision_score(y_test, lr_pred, pos_label=pos_label)
print(f"The precision score of the Logistic Regression model is {precision}")
precision = recall_score(y_test, lr_pred, pos_label=pos_label)
print(f"The recall score of the Logistic Regression model is {precision}")
print(f"the  f1_score of Logistic Regression model is {f1_score(y_test,lr_pred, pos_label=pos_label)}")
# Out:
# the accuracy of Logistic Regression model is 0.9473684210526315
# the confusion matrix of Logistic Regression model is [[69  1]
#  [ 5 39]]
# The precision score of the Logistic Regression model is 0.975
# The recall score of the Logistic Regression model is 0.8863636363636364
# the  f1_score of Logistic Regression model is 0.9285714285714285

# %%
import joblib

# Assuming 'model' is your trained model
# Replace 'model' with the actual variable name of your trained model

# Save the model to a file
joblib.dump(model_KNN, 'breast_cancer_model.pkl')
# Out:
# ['breast_cancer_model.pkl']
